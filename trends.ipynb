# %%
import pandas as pd
import numpy as np

# Read in the data
df = pd.read_csv('data/likes-weekly.csv')

# %%
# get # of model likes per week
df_model = df.loc[df['repoType'] == 'model']
df_model_likes = df_model.groupby(by=['name', 'date'], as_index=False)['likes'].sum()
df_model_likes
# Out:
#                                            name                      date  \
# 0                         01das/test_czech_gpt2  2022-11-06T00:00:00.000Z
# 1                           0x7194633/pyGPT-50M  2022-07-17T00:00:00.000Z
# 2               0xJustin/Dungeons-and-Diffusion  2022-11-06T00:00:00.000Z
# 3               0xJustin/Dungeons-and-Diffusion  2022-11-13T00:00:00.000Z
# 4                              123456/Arcanegan  2021-12-26T00:00:00.000Z
# ...                                         ...                       ...
# 21540  zoheb/mit-b5-finetuned-sidewalk-semantic  2022-10-09T00:00:00.000Z
# 21541                 zoheb/yolos-small-balloon  2022-10-16T00:00:00.000Z
# 21542                    zyayoung/cv-full-paper  2022-02-06T00:00:00.000Z
# 21543                 zzxslp/RadBERT-RoBERTa-4m  2022-10-23T00:00:00.000Z
# 21544                 zzxslp/RadBERT-RoBERTa-4m  2022-10-30T00:00:00.000Z
#
#        likes
# 0          1
# 1          1
# 2         37
# 3         31
# ...
